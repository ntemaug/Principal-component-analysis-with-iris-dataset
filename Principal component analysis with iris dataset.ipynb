# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
from sklearn.preprocessing import StandardScaler
# %matplotlib inline

# %%
food = ['SepalLength','x1','SepalWidth','x2','PetalLength','x3','petalWidth','x4','species']
df = pd.read_csv('iris.csv', names=food)

# %%
df.head()
# Out:
#    SepalLength        x1  SepalWidth        x2  PetalLength        x3  \
# 0          5.1  0.222222         3.5  0.625000          1.4  0.067797
# 1          4.9  0.166667         3.0  0.416667          1.4  0.067797
# 2          4.7  0.111111         3.2  0.500000          1.3  0.050847
# 3          4.6  0.083333         3.1  0.458333          1.5  0.084746
# 4          5.0  0.194444         3.6  0.666667          1.4  0.067797
#
#    petalWidth        x4 species
# 0         0.2  0.041667  setosa
# 1         0.2  0.041667  setosa
# 2         0.2  0.041667  setosa
# 3         0.2  0.041667  setosa
# 4         0.2  0.041667  setosa

# %%
df.shape
# Out:
# (100, 9)

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df=df.iloc[:,[0,2,4,6,8]]

# %%
df.head(2)
# Out:
#    SepalLength  SepalWidth  PetalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa

# %%
labels = df['species']
X = df.drop(['species'], axis = 1)

# %%
X_standard = StandardScaler()

# %%
X_standardized = StandardScaler().fit_transform(X)

# %%
# let us ask it to create a PCA with four features
#By passing all four features or components we are asking it to tell us howmany of them are useful
pca = PCA(n_components = 4)

X_transform = pca.fit_transform(X_standardized)

pca.explained_variance_
# Out:
# array([ 2.91362753,  0.91947418,  0.15295583,  0.01394246])

# %%
X_transform
# Out:
# array([[ -2.35601988e+00,   4.70699287e-01,  -9.99164200e-02,
#          -1.11813399e-02],
#        [ -2.16313468e+00,  -6.68989404e-01,  -2.39514373e-01,
#          -9.42463956e-02],
#        [ -2.44274712e+00,  -3.46089665e-01,   3.96928465e-02,
#          -1.04011976e-02],
#        [ -2.37495091e+00,  -5.99216622e-01,   7.32584340e-02,
#           8.41796798e-02],
#        [ -2.47943185e+00,   6.32895578e-01,   4.27628087e-02,
#           5.34002416e-02],
#        [ -2.17494683e+00,   1.46658741e+00,   9.21677438e-02,
#           8.70559830e-03],
#        [ -2.52009579e+00,   3.37125319e-02,   3.37587235e-01,
#           6.25414503e-02],
#        [ -2.32101217e+00,   2.16079486e-01,  -7.25020705e-02,
#           3.80815726e-02],
#        [ -2.40330098e+00,  -1.11293475e+00,   1.09633419e-01,
#           4.67516100e-02],
#        [ -2.26925217e+00,  -4.65300688e-01,  -2.61010939e-01,
#           4.86651016e-02],
#        [ -2.26707343e+00,   1.03137559e+00,  -2.18262575e-01,
# ...

# %%
#The first two components explain all the variance because adding them amoiunts to > 90& of the total variance
pca.explained_variance_ratio_
# Out:
# array([ 0.72840688,  0.22986854,  0.03823896,  0.00348561])

# %%
#X2 = X.iloc[:,0:2]
X_standard = StandardScaler()
X_standardized = StandardScaler().fit_transform(X)
pca1 = PCA(n_components = 2)
X2_transform = pca.fit_transform(X_standardized)

# %%
pca.explained_variance_
# Out:
# array([ 2.91362753,  0.91947418,  0.15295583,  0.01394246])

# %%
pca.explained_variance_ratio_
# Out:
# array([ 0.72840688,  0.22986854,  0.03823896,  0.00348561])

# %%
X2_transform
# Out:
# array([[ -2.35601988e+00,   4.70699287e-01,  -9.99164200e-02,
#          -1.11813399e-02],
#        [ -2.16313468e+00,  -6.68989404e-01,  -2.39514373e-01,
#          -9.42463956e-02],
#        [ -2.44274712e+00,  -3.46089665e-01,   3.96928465e-02,
#          -1.04011976e-02],
#        [ -2.37495091e+00,  -5.99216622e-01,   7.32584340e-02,
#           8.41796798e-02],
#        [ -2.47943185e+00,   6.32895578e-01,   4.27628087e-02,
#           5.34002416e-02],
#        [ -2.17494683e+00,   1.46658741e+00,   9.21677438e-02,
#           8.70559830e-03],
#        [ -2.52009579e+00,   3.37125319e-02,   3.37587235e-01,
#           6.25414503e-02],
#        [ -2.32101217e+00,   2.16079486e-01,  -7.25020705e-02,
#           3.80815726e-02],
#        [ -2.40330098e+00,  -1.11293475e+00,   1.09633419e-01,
#           4.67516100e-02],
#        [ -2.26925217e+00,  -4.65300688e-01,  -2.61010939e-01,
#           4.86651016e-02],
#        [ -2.26707343e+00,   1.03137559e+00,  -2.18262575e-01,
# ...
